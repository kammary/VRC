# %% [markdown]
# <a href="https://colab.research.google.com/github/kammary/VRC/blob/main/Untitled45.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load and preprocess the data
df = pd.read_json('/content/NEW DATASET.TRF (4).json') # Replace with your data file name

# %%
df.head()
# Out:
#    GDP DEFLATOR  NOMINAL GDP  SALES TAX REVENUES  \
# 0         100.0      16571.0               190.5
# 1         100.5      17394.0               161.9
# 2          97.0      17280.0               222.0
# 3         106.1      19732.0               273.1
# 4         116.6      22215.0               356.8
#
#    EXPOST DISCRETIONARY CHANGES  REAL GDP  REAL TAX REVENUES  \
# 0                           2.5   16571.0              190.5
# 1                           0.0   17300.6              161.0
# 2                          47.5   17821.8              229.0
# 3                          20.0   18606.3              257.5
# 4                           0.0   19047.4              305.9
#
#    REAL EXPOST DISCRETIONARY CHANGES  COEFF. OF CHANGE  \
# 0                                2.5               1.0
# 1                                0.0               1.0
# 2                               49.0               1.3
# 3                               18.9               1.1
# ...

# %%
df.isnull().sum()
# Out:
# GDP DEFLATOR                         0
# NOMINAL GDP                          0
# SALES TAX REVENUES                   0
# EXPOST DISCRETIONARY CHANGES         0
# REAL GDP                             0
# REAL TAX REVENUES                    0
# REAL EXPOST DISCRETIONARY CHANGES    0
# COEFF. OF CHANGE                     0
# CUMMM.COEFF. OF CHANGES              0
#  SALES TAX ADJUSTED                  0
# LOG REVENUE UNADJUSTED               0
# LOG REVENUE ADJUSTED                 0
# LOG GDP                              0
# LABEL                                0
# dtype: int64

# %%
# Drop rows with missing values in y_train
y_train = y_train.dropna()

# %%
x=df.iloc[:,:1].values
y=df.iloc[:, 1:2].values
print("x",x)
print("y",y)
# Out:
# x [[ 100.        ]
#  [ 100.5       ]
#  [  97.        ]
#  [ 106.1       ]
#  [ 116.6       ]
#  [ 125.5       ]
#  [ 135.5       ]
#  [ 148.1       ]
#  [ 166.3       ]
#  [ 176.9       ]
#  [ 100.        ]
#  [ 114.4       ]
#  [ 128.9       ]
#  [ 144.2       ]
#  [ 160.4       ]
#  [ 177.6       ]
#  [ 164.3       ]
#  [ 231.8       ]
#  [ 255.9       ]
#  [ 274.9       ]
#  [ 193.1       ]
#  [ 314.7       ]
#  [ 342.        ]
#  [ 273.28735178]
#  [ 282.02252964]
#  [ 290.75770751]
#  [ 299.49288538]
#  [ 308.22806324]
#  [ 316.96324111]
#  [ 325.69841897]
#  [ 334.43359684]
#  [ 343.1687747 ]
#  [ 351.90395257]
#  [ 360.63913043]
#  [ 369.3743083 ]
#  [ 378.10948617]
#  [ 386.84466403]
#  [ 395.5798419 ]
#  [ 404.31501976]
#  [ 413.05019763]
#  [ 421.78537549]
#  [ 430.52055336]
#  [ 439.25573123]
#  [ 447.99090909]
#  [ 456.72608696]
#  [ 465.46126482]
#  [ 474.19644269]
#  [ 482.93162055]
#  [ 491.66679842]
#  [ 500.40197628]
#  [ 509.13715415]
#  [ 517.87233202]
# ...

# %%
# Preprocess the data
# Assuming 'Revenue' is the target variable and the rest are features
X = df.drop('LOG GDP', axis=1)  # Features
y = df['REAL TAX REVENUES'] # Target variable
print("X",X)
print("y",y)
# Out:
# X      GDP DEFLATOR   NOMINAL GDP  SALES TAX REVENUES  \
# 0      100.000000  1.657100e+04          190.500000
# 1      100.500000  1.739400e+04          161.900000
# 2       97.000000  1.728000e+04          222.000000
# 3      106.100000  1.973200e+04          273.100000
# 4      116.600000  2.221500e+04          356.800000
# ..            ...           ...                 ...
# 191   1740.797233  2.082891e+06        51339.628458
# 192   1749.532411  2.093968e+06        51614.193182
# 193   1758.267589  2.105046e+06        51888.757905
# 194   1767.002767  2.116123e+06        52163.322628
# 195   1775.737945  2.127200e+06        52437.887352
#
#      EXPOST DISCRETIONARY CHANGES       REAL GDP  REAL TAX REVENUES  \
# 0                        2.500000   16571.000000         190.500000
# 1                        0.000000   17300.600000         161.000000
# 2                       47.500000   17821.800000         229.000000
# ...

# %%
# Split the dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)  # 90% training and 20% testing

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (176, 13)
# (176,)
# (20, 13)
# (20,)

# %%
imputer = SimpleImputer(strategy="mean")
X_train = imputer.fit_transform(X_train)

# %%
# Create a Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("y_pred")
print(y_pred)
print("y_test")
print(y_test)
# Out:
# y_pred
# [13387.53399209 10656.          1233.2         7154.06047431
#  14848.50434783 17867.843083    6012.          5206.1
#   1343.6        16309.47470356 15043.30039526   929.3
#  15530.29051383  5693.09011858 11049.98142292 10952.58339921
#  13971.92213439   435.6         6959.26442688 18062.63913043]
# y_test
# 139    13387.533992
# 113    10656.000000
# 16      1233.200000
# 75      7154.060474
# 154    14848.504348
# 185    17867.843083
# 69      6012.000000
# 55      5206.100000
# 18      1343.600000
# 169    16309.474704
# 156    15043.300395
# 15       929.300000
# 161    15530.290514
# 60      5693.090119
# 115    11049.981423
# 114    10952.583399
# 145    13971.922134
# 9        435.600000
# 73      6959.264427
# 187    18062.639130
# Name: REAL TAX REVENUES, dtype: float64
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
#Train the model using the training sets
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict the response for test dataset
y_pred = model.predict(X_test)
print("y_pred")
print(y_pred)
print("y_test")
print(y_test)
# Out:
# y_pred
# [13387.53399209 10656.          1233.2         7154.06047431
#  14848.50434783 17867.843083    6012.          5206.1
#   1343.6        16309.47470356 15043.30039526   929.3
#  15530.29051383  5693.09011858 11049.98142292 10952.58339921
#  13971.92213439   435.6         6959.26442688 18062.63913043]
# y_test
# 139    13387.533992
# 113    10656.000000
# 16      1233.200000
# 75      7154.060474
# 154    14848.504348
# 185    17867.843083
# 69      6012.000000
# 55      5206.100000
# 18      1343.600000
# 169    16309.474704
# 156    15043.300395
# 15       929.300000
# 161    15530.290514
# 60      5693.090119
# 115    11049.981423
# 114    10952.583399
# 145    13971.922134
# 9        435.600000
# 73      6959.264427
# 187    18062.639130
# Name: REAL TAX REVENUES, dtype: float64
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 1.0664167553398487e-23
# R-squared: 1.0

# %%
plt.plot(X_train,y_train,color='blue')
plt.plot(X_train, model.predict(X_train), color='red')
plt.title('REAL TAX REVENUES VS LOG GDP(training set)')
plt.xlabel('LOG GDP')
plt.ylabel('REAL TAX REVENUES')
plt.show()

# %%
# Plot the actual and forecasted tax revenue data
plt.plot(X_train, y_train, color='blue', label='Actual') # Plot the training data
plt.plot(X_test, y_test, color='red', label='Actual') # Plot the testing data
plt.plot(X_test, y_pred, color='green', label='Forecasted') # Plot the predicted data
plt.title('Tax Revenue Forecasting') # Add a title
plt.xlabel('LOG GDP') # Add a label for the x-axis
plt.ylabel('REAL TAX REVENUES (in millions)') # Add a label for the y-axis
plt.legend() # Add a legend
plt.show() # Show the plot

# %%
plt.plot(X_test, y_test, color='blue')
plt.plot(X_train, model.predict(X_train), color='green')
plt.title('REAL TAX REVENUES VS REAL GDP (training set)')
plt.title('Tax Revenue Forecasting') # Add a title
plt.xlabel('LOG GDP in figures')
plt.ylabel('REAL TAX REVENUES in rupees')
plt.show()
